# %%
# !pip install snowflake-connector-python
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import snowflake.connector

# %%
conn=snowflake.connector.connect(
    user='Hemavarsha',
    password='@Hemavarsha2006',
    account='RGUKXLT-LQ80779',
    database='IONOSPHERE_DB',
    schema='PUBLIC',
    warehouse='COMPUTE_WH'
)

# %%
query='select * from "IONOSPHERE_TABLE"'
df= pd.read_sql(query,conn)
# Out:
# C:\Users\hemav\AppData\Local\Temp\ipykernel_14332\2664728730.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df= pd.read_sql(query,conn)

# %%
print(df.head())
# Out:
#    COLUMN_A  COLUMN_B  COLUMN_C  COLUMN_D  COLUMN_E  COLUMN_F  COLUMN_G  \
# 0      True     False   0.99539  -0.05889   0.85243   0.02306   0.83398
# 1      True     False   1.00000  -0.18829   0.93035  -0.36156  -0.10868
# 2      True     False   1.00000  -0.03365   1.00000   0.00485   1.00000
# 3      True     False   1.00000  -0.45161   1.00000   1.00000   0.71216
# 4      True     False   1.00000  -0.02401   0.94140   0.06531   0.92106
#
#    COLUMN_H  COLUMN_I  COLUMN_J  ...  COLUMN_Z  COLUMN_AA  COLUMN_AB  \
# 0  -0.37708   1.00000   0.03760  ...  -0.51171    0.41078   -0.46168
# 1  -0.93597   1.00000  -0.04549  ...  -0.26569   -0.20468   -0.18401
# 2  -0.12062   0.88965   0.01198  ...  -0.40220    0.58984   -0.22145
# 3  -1.00000   0.00000   0.00000  ...   0.90695    0.51613    1.00000
# 4  -0.23255   0.77152  -0.16399  ...  -0.65158    0.13290   -0.53206
#
#    COLUMN_AC  COLUMN_AD  COLUMN_AE  COLUMN_AF  COLUMN_AG  COLUMN_AH  COLUMN_AI
# ...

# %%
conn.close()

# %%
df
# Out:
#      COLUMN_A  COLUMN_B  COLUMN_C  COLUMN_D  COLUMN_E  COLUMN_F  COLUMN_G  \
# 0        True     False   0.99539  -0.05889   0.85243   0.02306   0.83398
# 1        True     False   1.00000  -0.18829   0.93035  -0.36156  -0.10868
# 2        True     False   1.00000  -0.03365   1.00000   0.00485   1.00000
# 3        True     False   1.00000  -0.45161   1.00000   1.00000   0.71216
# 4        True     False   1.00000  -0.02401   0.94140   0.06531   0.92106
# ..        ...       ...       ...       ...       ...       ...       ...
# 346      True     False   0.83508   0.08298   0.73739  -0.14706   0.84349
# 347      True     False   0.95113   0.00419   0.95183  -0.02723   0.93438
# 348      True     False   0.94701  -0.00034   0.93207  -0.03227   0.95177
# 349      True     False   0.90608  -0.01657   0.98122  -0.01989   0.95691
# 350      True     False   0.84710   0.13533   0.73638  -0.06151   0.87873
#
#      COLUMN_H  COLUMN_I  COLUMN_J  ...  COLUMN_Z  COLUMN_AA  COLUMN_AB  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 35 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   COLUMN_A   351 non-null    bool
#  1   COLUMN_B   351 non-null    bool
#  2   COLUMN_C   351 non-null    float64
#  3   COLUMN_D   351 non-null    float64
#  4   COLUMN_E   351 non-null    float64
#  5   COLUMN_F   351 non-null    float64
#  6   COLUMN_G   351 non-null    float64
#  7   COLUMN_H   351 non-null    float64
#  8   COLUMN_I   351 non-null    float64
#  9   COLUMN_J   351 non-null    float64
#  10  COLUMN_K   351 non-null    float64
#  11  COLUMN_L   351 non-null    float64
#  12  COLUMN_M   351 non-null    float64
#  13  COLUMN_N   351 non-null    float64
#  14  COLUMN_O   351 non-null    float64
#  15  COLUMN_P   351 non-null    float64
#  16  COLUMN_Q   351 non-null    float64
#  17  COLUMN_R   351 non-null    float64
#  18  COLUMN_S   351 non-null    float64
# ...

# %%
df.describe()
# Out:
#          COLUMN_C    COLUMN_D    COLUMN_E    COLUMN_F    COLUMN_G    COLUMN_H  \
# count  351.000000  351.000000  351.000000  351.000000  351.000000  351.000000
# mean     0.641342    0.044372    0.601068    0.115889    0.550095    0.119360
# std      0.497708    0.441435    0.519862    0.460810    0.492654    0.520750
# min     -1.000000   -1.000000   -1.000000   -1.000000   -1.000000   -1.000000
# 25%      0.472135   -0.064735    0.412660   -0.024795    0.211310   -0.054840
# 50%      0.871110    0.016310    0.809200    0.022800    0.728730    0.014710
# 75%      1.000000    0.194185    1.000000    0.334655    0.969240    0.445675
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#          COLUMN_I    COLUMN_J    COLUMN_K    COLUMN_L  ...    COLUMN_Y  \
# count  351.000000  351.000000  351.000000  351.000000  ...  351.000000
# mean     0.511848    0.181345    0.476183    0.155040  ...    0.396135
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.iloc[:,0:33]
x
# Out:
#      COLUMN_A  COLUMN_B  COLUMN_C  COLUMN_D  COLUMN_E  COLUMN_F  COLUMN_G  \
# 0        True     False   0.99539  -0.05889   0.85243   0.02306   0.83398
# 1        True     False   1.00000  -0.18829   0.93035  -0.36156  -0.10868
# 2        True     False   1.00000  -0.03365   1.00000   0.00485   1.00000
# 3        True     False   1.00000  -0.45161   1.00000   1.00000   0.71216
# 4        True     False   1.00000  -0.02401   0.94140   0.06531   0.92106
# ..        ...       ...       ...       ...       ...       ...       ...
# 346      True     False   0.83508   0.08298   0.73739  -0.14706   0.84349
# 347      True     False   0.95113   0.00419   0.95183  -0.02723   0.93438
# 348      True     False   0.94701  -0.00034   0.93207  -0.03227   0.95177
# 349      True     False   0.90608  -0.01657   0.98122  -0.01989   0.95691
# 350      True     False   0.84710   0.13533   0.73638  -0.06151   0.87873
#
#      COLUMN_H  COLUMN_I  COLUMN_J  ...  COLUMN_X  COLUMN_Y  COLUMN_Z  \
# ...

# %%
y=df['COLUMN_AI']
y
# Out:
# 0      g
# 1      b
# 2      g
# 3      b
# 4      g
#       ..
# 346    g
# 347    g
# 348    g
# 349    g
# 350    g
# Name: COLUMN_AI, Length: 351, dtype: object

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.8309859154929577

# %%
from sklearn.naive_bayes import GaussianNB
model1=GaussianNB()

# %%
model1.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred1=model1.predict(x_test)

# %%
accuracy1=accuracy_score(y_test,y_pred1)
accuracy1
# Out:
# 0.8732394366197183

# %%
from sklearn.linear_model import LogisticRegression
model2=LogisticRegression()

# %%
model2.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred2=model2.predict(x_test)

# %%
accuracy2=accuracy_score(y_test,y_pred2)
accuracy2
# Out:
# 0.8591549295774648

# %%
import pickle
with open("model.pkl","wb") as f:       #for downloading the model to local system using pkl(pickle is suitable for small analysis or classification)
    pickle.dump(model,f)                #if any neural networks involved,go with hdf5

# %%
with open("model.pkl","rb") as f:
    loaded_model=pickle.load(f)

# %%
import joblib                          #for downloading the model to local system using joblib
joblib.dump(model,"model.pkl")
# Out:
# ['model.pkl']

# %%
model=joblib.load("model.pkl")        #load the model
